# %%
Текстовая ячейка <8ZWwQ2qDRSnV>
# %% [markdown]
**Варіант №1**

Текстовая ячейка <tRJVygW8RVQT>
# %% [markdown]
**Завдання 1**

Завантажити датасет Ірис. Роздрукувати перші 5 рядочків.
Методом ліктя і методом силуєтів визначити оптимальну кількість кластерів.
Візуалізувати кластери.

Кодовая ячейка <z7C0Y1aqSEVU>
# %% [code]
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler


Кодовая ячейка <N8DWn15VTfLM>
# %% [code]
iris = load_iris()
x = iris.data

pd.DataFrame(x, columns=iris.feature_names).head()
Получены выходные данные.
11KB
	text/plain
		sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
		0                5.1               3.5                1.4               0.2
		1                4.9               3.0                1.4               0.2
		2                4.7               3.2                1.3               0.2
		3                4.6               3.1                1.5               0.2
		4                5.0               3.6                1.4               0.2

Кодовая ячейка <9cbct6mfTlNT>
# %% [code]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)
X_2d = pd.DataFrame(X_scaled, columns=iris.feature_names).iloc[:,1:]

wcss_2d = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
  kmeans.fit(X_2d)
  wcss_2d.append(kmeans.inertia_)

plt.figure(figsize = (5, 3))
plt.plot(range(1,11), wcss_2d, marker='o', linestyle='--')
plt.title('Elbow Method after scaling')
plt.xlabel('Number of clusters')
plt.ylabel('Within-clusters Sum of Squares')
plt.grid(True)
plt.show()
Получены выходные данные.
30KB
	text/plain
		<Figure size 500x300 with 1 Axes>

Кодовая ячейка <Wadg_Y46UEqO>
# %% [code]
silhouette_scores = []
for i in range(2,11):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
  cluster_labels = kmeans.fit_predict(X_2d)
  silhouette_avg = silhouette_score(X_2d, cluster_labels)
  silhouette_scores.append(silhouette_avg)

plt.figure(figsize = (5, 3))
plt.plot(range(2,11), silhouette_scores, marker='o', linestyle='--')
plt.title('Silhouette Method after scaling')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()
Получены выходные данные.
31KB
	text/plain
		<Figure size 500x300 with 1 Axes>

Кодовая ячейка <2eSCKaOUUH4Q>
# %% [code]
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300, n_init=10, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

plt.figure(figsize=(7,5))
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,1], hue=clusters, palette='viridis', legend='full')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red', label='Centroids')
plt.title('KMeans Clusterint')
plt.xlabel('Feature 1 (Scaled)')
plt.ylabel('Feature 2 (Scaled)')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
Получены выходные данные.
55KB
	text/plain
		<Figure size 700x500 with 1 Axes>

Текстовая ячейка <xyhfVu4CUSj3>
# %% [markdown]
**ВИСНОВОК**

У цій лабороторній роботі було завантажено датасет Ірис і застосовано методи ліктя та силуетів для визначення оптимальної кількості кластерів. Обидва методи вказали на 3 кластери як оптимальні. Також було зроблено графічну візуалізацію.

Текстовая ячейка <cZforyufVDNX>
# %% [markdown]
**Завдання 2**

Завантажити датасет Student_data.csv (датасет з Kaggle)

Кодовая ячейка <dcp8Y7V1WVs1>
# %% [code]
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from google.colab import files
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

Кодовая ячейка <S7_FuyUBWdo->
# %% [code]
data = files.upload()
df = pd.read_csv(next(iter(data)))
Получены выходные данные.
6KB
	Stream
		Saving Student_data.csv to Student_data.csv

Текстовая ячейка <HDzM8PG7Wnz6>
# %% [markdown]
Роздрукувати перші 5 рядків.

Кодовая ячейка <vdeK5YdJWpsO>
# %% [code]
df.head()
Получены выходные данные.
17KB
	text/plain
		StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
		0       1001   17       1          0                  2        19.833723
		1       1002   18       0          0                  1        15.408756
		2       1003   15       0          2                  3         4.210570
		3       1004   17       1          0                  3        10.028829
		4       1005   17       1          0                  2         4.672495

		   Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
		0         7         1                2                0       0      1
		1         0         0                1                0       0      0
		2        26         0                2                0       0      0
		3        14         0                3                1       0      0
		4        17         1                3                0       0      0

		   Volunteering       GPA  GradeClass
		0             0  2.929196         2.0
		1             0  3.042915         1.0
		2             0  0.112602         4.0
		3             0  2.054218         3.0
		4             0  1.288061         4.0

Текстовая ячейка <JgrBJI2mWtDo>
# %% [markdown]
Вивести розмір датасета, типи даних.

Кодовая ячейка <zkrcKmcOWuso>
# %% [code]
df.dtypes
Получены выходные данные.
2KB
	text/plain
		StudentID              int64
		Age                    int64
		Gender                 int64
		Ethnicity              int64
		ParentalEducation      int64
		StudyTimeWeekly      float64
		Absences               int64
		Tutoring               int64
		ParentalSupport        int64
		Extracurricular        int64
		Sports                 int64
		Music                  int64
		Volunteering           int64
		GPA                  float64
		GradeClass           float64
		dtype: object

Кодовая ячейка <4Ji_8LQQWyCe>
# %% [code]
df.shape
Получены выходные данные.
0KB
	text/plain
		(2392, 15)

Текстовая ячейка <tOE46XhNWy2T>
# %% [markdown]
Перевірити на пропущені значення. При наявності замінити на середнє за
стовпцем.

Кодовая ячейка <aTyzjJ6qW1an>
# %% [code]
df.isnull().sum()
Получены выходные данные.
2KB
	text/plain
		StudentID            0
		Age                  0
		Gender               0
		Ethnicity            0
		ParentalEducation    0
		StudyTimeWeekly      0
		Absences             0
		Tutoring             0
		ParentalSupport      0
		Extracurricular      0
		Sports               0
		Music                0
		Volunteering         0
		GPA                  0
		GradeClass           0
		dtype: int64

Текстовая ячейка <1QdWUPbEW32d>
# %% [markdown]
Перевірити на дублікати. Якщо є – видалити.

Кодовая ячейка <dP0OcNQwW7L4>
# %% [code]
df.duplicated()
Получены выходные данные.
2KB
	text/plain
		0       False
		1       False
		2       False
		3       False
		4       False
		        ...
		2387    False
		2388    False
		2389    False
		2390    False
		2391    False
		Length: 2392, dtype: bool

Текстовая ячейка <bLi_7GZgW_wW>
# %% [markdown]
 Вивести описову статистику.

Кодовая ячейка <8-sqNvdkXCSt>
# %% [code]
df.describe()
Получены выходные данные.
20KB
	text/plain
		StudentID          Age       Gender    Ethnicity  ParentalEducation  \
		count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
		mean   2196.500000    16.468645     0.510870     0.877508           1.746237
		std     690.655244     1.123798     0.499986     1.028476           1.000411
		min    1001.000000    15.000000     0.000000     0.000000           0.000000
		25%    1598.750000    15.000000     0.000000     0.000000           1.000000
		50%    2196.500000    16.000000     1.000000     0.000000           2.000000
		75%    2794.250000    17.000000     1.000000     2.000000           2.000000
		max    3392.000000    18.000000     1.000000     3.000000           4.000000

		       StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
		count      2392.000000  2392.000000  2392.000000      2392.000000
		mean          9.771992    14.541388     0.301421         2.122074
		std           5.652774     8.467417     0.458971         1.122813
		min           0.001057     0.000000     0.000000         0.000000
		25%           5.043079     7.000000     0.000000         1.000000
		50%           9.705363    15.000000     0.000000         2.000000
		75%          14.408410    22.000000     1.000000         3.000000
		max          19.978094    29.000000     1.000000         4.000000

		       Extracurricular       Sports        Music  Volunteering          GPA  \
		count      2392.000000  2392.000000  2392.000000   2392.000000  2392.000000
		mean          0.383361     0.303512     0.196906      0.157191     1.906186
		std           0.486307     0.459870     0.397744      0.364057     0.915156
		min           0.000000     0.000000     0.000000      0.000000     0.000000
		25%           0.000000     0.000000     0.000000      0.000000     1.174803
		50%           0.000000     0.000000     0.000000      0.000000     1.893393
		75%           1.000000     1.000000     0.000000      0.000000     2.622216
		max           1.000000     1.000000     1.000000      1.000000     4.000000

		        GradeClass
		count  2392.000000
		mean      2.983696
		std       1.233908
		min       0.000000
		25%       2.000000
		50%       4.000000
		75%       4.000000
		max       4.000000

Текстовая ячейка <AFpfJ_r4XFOF>
# %% [markdown]
Побудувати 3
моделі на вибір для визначення оцінки. Підібрати оптимальні параметри.
Оцінити моделі.

Кодовая ячейка <Kn6xkmnBcrku>
# %% [code]
X = df.drop(['GradeClass'], axis=1)
y = df['GradeClass']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

Кодовая ячейка <_1ODeqmZcurx>
# %% [code]
# Логістична регресія

logreg = LogisticRegression(max_iter=1000)
logreg_params = {
    'C': [0.1, 1, 10],
    'penalty': ['l2']
}

logreg_grid = GridSearchCV(logreg, logreg_params, cv=5)
logreg_grid.fit(X_train, y_train)
logreg_best = logreg_grid.best_estimator_


Кодовая ячейка <2Unm9N7Bc2bY>
# %% [code]
# Дерево рішень

tree = DecisionTreeClassifier(random_state=42)
tree_params = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]
}

tree_grid = GridSearchCV(tree, tree_params, cv=5)
tree_grid.fit(X_train, y_train)
tree_best = tree_grid.best_estimator_

Кодовая ячейка <FGr8ESj8c6NG>
# %% [code]
# SVM

svm = SVC()
svm_params = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}
svm_grid = GridSearchCV(svm, svm_params, cv=5)
svm_grid.fit(X_train, y_train)
svm_best = svm_grid.best_estimator_


Кодовая ячейка <Tp9lITLMdYFe>
# %% [code]
# Оцінка моделей

models = {'Logistic Regression': logreg_best, 'Decision Tree': tree_best, 'SVM': svm_best}

for model_name, model in models.items():
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{model_name} Accuracy: {accuracy}")
Получены выходные данные.
0KB
	Stream
		Logistic Regression Accuracy: 0.7284122562674095
		Decision Tree Accuracy: 0.924791086350975
		SVM Accuracy: 0.8481894150417827

Текстовая ячейка <oY0HTONEdgKY>
# %% [markdown]
Визначити методом ліктя і силуєтів оптимальну кількість кластерів.

Кодовая ячейка <ZAXaT3ZWdgj9>
# %% [code]
features = df[['Age', 'StudyTimeWeekly', 'Absences', 'GPA']]
scaler = StandardScaler()
X_scalerd = scaler.fit_transform(features)

wcss_2d = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
  kmeans.fit(X_scalerd)
  wcss_2d.append(kmeans.inertia_)

plt.figure(figsize = (5, 3))
plt.plot(range(1,11), wcss_2d, marker='o', linestyle='--')
plt.title('Elbow Method after scaling')
plt.xlabel('Number of clusters')
plt.ylabel('Within-clusters Sum of Squares')
plt.grid(True)
plt.show()
Получены выходные данные.
32KB
	text/plain
		<Figure size 500x300 with 1 Axes>

Кодовая ячейка <vD9dvUbWdmmi>
# %% [code]
silhouette_scores = []
for i in range(2,11):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
  cluster_labels = kmeans.fit_predict(X_scalerd)
  silhouette_avg = silhouette_score(X_scalerd, cluster_labels)
  silhouette_scores.append(silhouette_avg)

plt.figure(figsize = (5, 3))
plt.plot(range(2,11), silhouette_scores, marker='o', linestyle='--')
plt.title('Silhouette Method after scaling')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()
Получены выходные данные.
33KB
	text/plain
		<Figure size 500x300 with 1 Axes>

Текстовая ячейка <j-7J2gUQdtLc>
# %% [markdown]
**ВИСНОВОК**

Було проведено аналіз датасету Student_data.csv, включаючи різні операції з обробки даних, такі як видалення дублікатів та отримання описової статистики. Далі було побудовано та оцінено три моделі. Для визначення оптимальної кількості кластерів використовували метод ліктя та метод силуетів.
