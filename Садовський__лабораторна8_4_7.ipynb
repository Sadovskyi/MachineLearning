# %%
Текстовая ячейка <gKDvZQw9DXB2>
# %% [markdown]
**ВАРІАНТ 1**

Текстовая ячейка <WbZQcuyjDaIR>
# %% [markdown]
**ЗАВДАННЯ 1**

Текстовая ячейка <69P9rUYdIcPb>
# %% [markdown]
Побудувати звичайну багатошарову нейронну мережу для датасету fashion
mnist

Текстовая ячейка <0Rk2NWy0Ig24>
# %% [markdown]
1. Завантажити датасет

Кодовая ячейка <R6O2qI1MIhP7>
# %% [code]
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os

Кодовая ячейка <xfO6gR9lIrnI>
# %% [code]
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
Получены выходные данные.
1KB
	Stream
		Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
		[1m29515/29515[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 0us/step
		Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
		[1m26421880/26421880[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 0us/step
		Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
		[1m5148/5148[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 1us/step
		Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
		[1m4422102/4422102[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 0us/step

Кодовая ячейка <zSkr3pF4I5Gc>
# %% [code]
# Імена класів
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

Текстовая ячейка <bGvGtQfaI7v7>
# %% [markdown]
2. Роздрукувати 10 зображень.

Кодовая ячейка <MYYXstgdI8Bg>
# %% [code]
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()
Получены выходные данные.
48KB
	text/plain
		<Figure size 1000x1000 with 10 Axes>

Текстовая ячейка <0Zs140QPI_61>
# %% [markdown]
3. Підготовувати дані, побудувати архітектуру
5. Вивести архітектуру моделі.

Кодовая ячейка <uu-UzpPgJBTe>
# %% [code]
train_images = train_images / 255.0
test_images = test_images / 255.0

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
Получены выходные данные.
6KB
	text/plain
		[1mModel: "sequential_1"[0m
		┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
		┃[1m [0m[1mLayer (type)                        [0m[1m [0m┃[1m [0m[1mOutput Shape               [0m[1m [0m┃[1m [0m[1m        Param #[0m[1m [0m┃
		┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
		│ flatten_1 ([38;5;33mFlatten[0m)                  │ ([38;5;45mNone[0m, [38;5;34m784[0m)                 │               [38;5;34m0[0m │
		├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
		│ dense_4 ([38;5;33mDense[0m)                      │ ([38;5;45mNone[0m, [38;5;34m512[0m)                 │         [38;5;34m401,920[0m │
		├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
		│ dense_5 ([38;5;33mDense[0m)                      │ ([38;5;45mNone[0m, [38;5;34m256[0m)                 │         [38;5;34m131,328[0m │
		├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
		│ dense_6 ([38;5;33mDense[0m)                      │ ([38;5;45mNone[0m, [38;5;34m128[0m)                 │          [38;5;34m32,896[0m │
		├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
		│ dense_7 ([38;5;33mDense[0m)                      │ ([38;5;45mNone[0m, [38;5;34m10[0m)                  │           [38;5;34m1,290[0m │
		└──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
		[1m Total params: [0m[38;5;34m567,434[0m (2.16 MB)
		[1m Trainable params: [0m[38;5;34m567,434[0m (2.16 MB)
		[1m Non-trainable params: [0m[38;5;34m0[0m (0.00 B)

Текстовая ячейка <ggJvZhAGJmsk>
# %% [markdown]
4. Використати ранню зупинку і зменшення швидкості для запобіганню
перенавчанню

Кодовая ячейка <6DARr7xEJnGa>
# %% [code]
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=
50
		[1m1875/1875[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m17s[0m 9ms/step - accuracy: 0.9240 - loss: 0.2021 - val_accuracy: 0.8938 - val_loss: 0.3095 - learning_rate: 4.0000e-05
		Epoch 20/50
		[1m1875/1875[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m19s[0m 10ms/step - accuracy: 0.9276 - loss: 0.1976 - val_accuracy: 0.8926 - val_loss: 0.3086 - learning_rate: 4.0000e-05
		Epoch 21/50
		[1m1875/1875[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m19s[0m 9ms/step - accuracy: 0.9251 - loss: 0.2015 - val_accuracy: 0.8933 - val_loss: 0.3095 - learning_rate: 4.0000e-05
		Epoch 22/50
		[1m1875/1875[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m17s[0m 9ms/step - accuracy: 0.9242 - loss: 0.2006 - val_accuracy: 0.8932 - val_loss: 0.3102 - learning_rate: 4.0000e-05
		Epoch 23/50
		[1m1875/1875[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m21s[0m 9ms/step - accuracy: 0.9257 - loss: 0.1991 - val_accuracy: 0.8932 - val_loss: 0.3092 - learning_rate: 8.0000e-06

Текстовая ячейка <71DLG2ebLhyC>
# %% [markdown]
6. Зберегти модель на гугл диск.

Кодовая ячейка <cfRqmvSWLiLR>
# %% [code]
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/fashion_mnist_model.h5')
Получены выходные данные.
0KB
	Stream
		WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
		Mounted at /content/drive

Текстовая ячейка <zRKgf7GQL6iJ>
# %% [markdown]
7. Побудувати графіки функції втрат і точності для тренувальних і
тестових даних

Кодовая ячейка <3csU9y-5L7it>
# %% [code]
plt.figure(figsize=(9, 3))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Витрати')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Точності')
plt.grid(True)
plt.legend()

plt.show()
Получены выходные данные.
46KB
	text/plain
		<Figure size 900x300 with 2 Axes>

Текстовая ячейка <qyNL08GPMN5l>
# %% [markdown]
8. Вивести класифікаційний звіт.

Кодовая ячейка <jcDIimg_MRaO>
# %% [code]
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
predictions = model.predict(test_images)

predicted_labels = np.argmax(predictions, axis=1)

print(classification_report(test_labels, predicted_labels, target_names=class_names))
Получены выходные данные.
1KB
	Stream
		313/313 - 1s - 2ms/step - accuracy: 0.8926 - loss: 0.3086
		[1m313/313[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m1s[0m 4ms/step
		              precision    recall  f1-score   support

		 T-shirt/top       0.86      0.85      0.85      1000
		     Trouser       0.99      0.97      0.98      1000
		    Pullover       0.82      0.81      0.81      1000
		       Dress       0.88      0.92      0.90      1000
		        Coat       0.81      0.83      0.82      1000
		      Sandal       0.98      0.95      0.96      1000
		       Shirt       0.73      0.70      0.72      1000
		     Sneaker       0.93      0.96      0.95      1000
		         Bag       0.98      0.98      0.98      1000
		  Ankle boot       0.96      0.96      0.96      1000

		    accuracy                           0.89     10000
		   macro avg       0.89      0.89      0.89     10000
		weighted avg       0.89      0.89      0.89     10000

Текстовая ячейка <_8NP1P3gMVue>
# %% [markdown]
9. Результати розпізнавання із прогнозованим і справжнім класом

Кодовая ячейка <E3Jdhl0MMWCl>
# %% [code]
plt.figure(figsize=(10, 10))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel(f"Pred: {class_names[predicted_labels[i]]}\nTrue: {class_names[test_labels[i]]}")
plt.show()
Получены выходные данные.
55KB
	text/plain
		<Figure size 1000x1000 with 10 Axes>

Текстовая ячейка <s10pMIgWMrtW>
# %% [markdown]
**ЗАВДАННЯ 2**

Текстовая ячейка <vU25I20lM04K>
# %% [markdown]
Побудувати нейронну мережу, аналогічну завданню 1 для датасета fashion
mnist

Кодовая ячейка <D-bKC4QsNVSY>
# %% [code]
# !pip install keras-tuner -q
Получены выходные данные.
1KB
	Stream
		[?25l   [90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━[0m [32m0.0/129.1 kB[0m [31m?[0m eta [36m-:--:--[0m
[2K   [91m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━[0m[90m╺[0m[90m━[0m [32m122.9/129.1 kB[0m [31m4.4 MB/s[0m eta [36m0:00:01[0m
[2K   [90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━[0m [32m129.1/129.1 kB[0m [31m2.8 MB/s[0m eta [36m0:00:00[0m
		[?25h

Кодовая ячейка <wiBWF_v1NaZ4>
# %% [code]
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from kerastuner.tuners import RandomSearch
Получены выходные данные.
0KB
	Stream
		<ipython-input-20-5270575026c6>:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
		  from kerastuner.tuners import RandomSearch

Кодовая ячейка <ieNWh0FTNjgG>
# %% [code]
fashion_mnist = keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print("x_train original shape", x_train.shape)
print("y_train original shape", y_train.shape)

x_train = x_train / 255.0
x_test = x_test / 255.0
Получены выходные данные.
0KB
	Stream
		x_train original shape (60000, 28, 28)
		y_train original shape (60000,)

Кодовая ячейка <OIWxK_L0NvRZ>
# %% [code]
def build_model(hp):
    model = keras.Sequential()
    model.add(Flatten(input_shape=(28, 28)))

    # Додавання шарів, які будуть тюнуватися
    for i in range(hp.Int('num_layers', 1, 4)):
        model.add(Dense(units=hp.Int('units_' + str(i),
                                     min_value=32,
                                     max_value=512,
                                     step=32),
                        activation='relu',
                        kernel_regularizer=l2(0.001)))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

    model.add(Dense(10, activation='softmax'))

    # Компіляція моделі з оптимізатором, який також буде тюнуватися
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # збільшення кількості спроб для кращих результатів
    executions_per_trial=1,
    directory='tuner_logs',
    project_name='fashion_mnist_classification'
)
# Визначення ранньої зупинки та зниження швидкості навчання
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping, reduce_lr])

# Отримання найкращої моделі
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()

# Тренування та оцінка моделі
best_model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping, reduce_lr])

test_loss, test_acc = best_model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
Получены выходные данные.
1KB
	Stream
		Trial 4 Complete [00h 34m 34s]
		val_accuracy: 0.8924000263214111

		Best val_accuracy So Far: 0.8952999711036682
		Total elapsed time: 01h 20m 56s

		Search: Running Trial #5

		Value             |Best Value So Far |Hyperparameter
		3                 |4                 |num_layers
		192               |160               |units_0
		0.01              |0.0001            |learning_rate
		160               |192               |units_1
		416               |416               |units_2
		512               |32                |units_3

		Epoch 1/50
		[1m1130/1875[0m [32m━━━━━━━━━━━━[0m[37m━━━━━━━━[0m [1m9s[0m 13ms/step - accuracy: 0.6572 - loss: 1.9829

Текстовая ячейка <rlJEMABbesOx>
# %% [markdown]
**ВИСНОВОК**

Друга модель, яка використовує Keras Tuner для оптимізації гіперпараметрів, показала кращу точність (89.53%) в порівнянні з першою моделлю (89.26%). Завдяки автоматизованому підбору параметрів, модель 2 змогла покращити показники.
